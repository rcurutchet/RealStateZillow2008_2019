# %%
# Importing Libraries
import pandas as pd 
from pandas import DataFrame
import matplotlib
# %matplotlib inline 
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## GRAPH 1 - House Values
# Purpose: Show the evolution of Real Estate prices for different counties of the United States.

# %%
# Dataframe for Graph 1
df_graph1 = pd.read_csv('group11_value_1bed.csv')
df_graph1.head()
# Out:
#    RegionID          RegionName State                             Metro  \
# 0      3101  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook County    IL          Chicago-Naperville-Elgin
# 2      1090       Harris County    TX  Houston-The Woodlands-Sugar Land
# 3      2841    San Diego County    CA                San Diego-Carlsbad
# 4      1286       Orange County    CA    Los Angeles-Long Beach-Anaheim
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank   1996-04   1996-05   1996-06  \
# 0              6                 37         1   92800.0   92600.0   92300.0
# 1             17                 31         2  100500.0  100300.0  100100.0
# 2             48                201         3   49000.0   49000.0   49000.0
# 3              6                 73         4   78300.0   77500.0   76800.0
# 4              6                 59         5   86200.0   85900.0   85600.0
#
#     ...     2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 0   ...      440400   441600   443100   444900   445500   445900   446800
# 1   ...      160300   159700   161400   163700   165000   165700   166500
# 2   ...       86700    87600    88200    88700    89400    90000    89800
# 3   ...      327000   328200   329000   330000   330600   330800   330200
# 4   ...      348600   349300   349800   351100   352600   353300   352800
#
#    2019-02  2019-03  2019-04
# 0   446400   445300   444700
# 1   166800   166300   164700
# 2    89500    89000    88400
# 3   329800   331500   333900
# 4   352200   351100   349800
#
# [5 rows x 284 columns]

# %%
# Santa Clara County Data 
sc_county = df_graph1[df_graph1.RegionName == 'Santa Clara County']
sc_county
# Out:
#     RegionID          RegionName State                           Metro  \
# 12      3136  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara
#
#     StateCodeFIPS  MunicipalCodeFIPS  SizeRank   1996-04   1996-05   1996-06  \
# 12              6                 85        13  133200.0  133100.0  133100.0
#
#      ...     2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 12   ...      668600   672300   682400   691600   694500   692300   689900
#
#     2019-02  2019-03  2019-04
# 12   685400   676700   666300
#
# [1 rows x 284 columns]

# %%
# Los Angeles County Data 
la_county = df_graph1[df_graph1.RegionName == 'Los Angeles County']
la_county
# Out:
#    RegionID          RegionName State                           Metro  \
# 0      3101  Los Angeles County    CA  Los Angeles-Long Beach-Anaheim
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# 0              6                 37         1  92800.0  92600.0  92300.0
#
#     ...     2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 0   ...      440400   441600   443100   444900   445500   445900   446800
#
#    2019-02  2019-03  2019-04
# 0   446400   445300   444700
#
# [1 rows x 284 columns]

# %%
# Cuyahoga County Data 
c_county = df_graph1[df_graph1.RegionName == 'Cuyahoga County']
c_county
# Out:
#     RegionID       RegionName State             Metro  StateCodeFIPS  \
# 21      2241  Cuyahoga County    OH  Cleveland-Elyria             39
#
#     MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06   ...     2018-07  \
# 21                 35        22  48200.0  48400.0  48500.0   ...       61400
#
#     2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  2019-02  2019-03  \
# 21    61700    61700    61700    62400    63100    63500    63400    63200
#
#     2019-04
# 21    62700
#
# [1 rows x 284 columns]

# %%
# King County Data
k_county = df_graph1[df_graph1.RegionName == 'King County']
k_county
# Out:
#     RegionID   RegionName State                    Metro  StateCodeFIPS  \
# 10       207  King County    WA  Seattle-Tacoma-Bellevue             53
#
#     MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06   ...     2018-07  \
# 10                 33        11  87400.0  87300.0  87300.0   ...      360400
#
#     2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  2019-02  2019-03  \
# 10   360800   362900   363400   362300   361400   361200   359800   357300
#
#     2019-04
# 10   354400
#
# [1 rows x 284 columns]

# %%
# Tarrant County Data 
t_county = df_graph1[df_graph1.RegionName == 'Tarrant County']
t_county
# Out:
#     RegionID      RegionName State                        Metro  \
# 11      2049  Tarrant County    TX  Dallas-Fort Worth-Arlington
#
#     StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# 11             48                439        12  53800.0  53700.0  53500.0
#
#      ...     2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 11   ...      122700   121800   120800   120700   121700   122800   123900
#
#     2019-02  2019-03  2019-04
# 11   124000   122100   119400
#
# [1 rows x 284 columns]

# %% [markdown]
# ### Creating a new Dataframe with the information found above:

# %%
# Gathering information into a new Dataframe
new_df_1 = df_graph1.iloc[[12, 0, 21, 10, 11], :]
new_df_1
# Out:
#     RegionID          RegionName State                           Metro  \
# 12      3136  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara
# 0       3101  Los Angeles County    CA  Los Angeles-Long Beach-Anaheim
# 21      2241     Cuyahoga County    OH                Cleveland-Elyria
# 10       207         King County    WA         Seattle-Tacoma-Bellevue
# 11      2049      Tarrant County    TX     Dallas-Fort Worth-Arlington
#
#     StateCodeFIPS  MunicipalCodeFIPS  SizeRank   1996-04   1996-05   1996-06  \
# 12              6                 85        13  133200.0  133100.0  133100.0
# 0               6                 37         1   92800.0   92600.0   92300.0
# 21             39                 35        22   48200.0   48400.0   48500.0
# 10             53                 33        11   87400.0   87300.0   87300.0
# 11             48                439        12   53800.0   53700.0   53500.0
#
#      ...     2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 12   ...      668600   672300   682400   691600   694500   692300   689900
# 0    ...      440400   441600   443100   444900   445500   445900   446800
# 21   ...       61400    61700    61700    61700    62400    63100    63500
# 10   ...      360400   360800   362900   363400   362300   361400   361200
# 11   ...      122700   121800   120800   120700   121700   122800   123900
#
#     2019-02  2019-03  2019-04
# 12   685400   676700   666300
# 0    446400   445300   444700
# 21    63400    63200    62700
# 10   359800   357300   354400
# 11   124000   122100   119400
#
# [5 rows x 284 columns]

# %%
# Renaming a Column
new_df_2 = new_df_1.rename(columns = {'2019-04':'april2019'})

# Checking
new_df_2['april2019']
# Out:
# 12    666300
# 0     444700
# 21     62700
# 10    354400
# 11    119400
# Name: april2019, dtype: int64

# %%
# Plotting Graph 1
graph_1 = sns.barplot(x = new_df_2.RegionName, y = new_df_2.april2019)

# Creating function for wisting labels for fitting
def twist(graph):
    """Twist labels to 40 degrees angle"""
    graph.set_xticklabels(graph.get_xticklabels(), rotation = 40, ha = 'right')
    plt.tight_layout()
    plt.show()
twist(graph_1)

# %%
# Saving Graph 1
fig = graph_1.get_figure()
fig.savefig('group11_graph1.png', bbox_inches = 'tight')

# %% [markdown]
# ### GRAPH 2 - Houses Sold per County
#
# Purpose: show how many houses were sold in different counties in 06/2008, 06/2009 (immediately after recession) , 06/2013 (5 years after 2008’s recession) and in 06/2018 (10 years after recession) - this graph will mainly show the impact of 2008 economic crisis in the Real Estate Market.

# %%
# Dataframe for Graph 2
soldhomes = pd.read_csv('group11_homes_sold.csv')

# Checking
soldhomes.head()
# Out:
#    RegionID          RegionName   StateName  SizeRank  2008-03  2008-04  \
# 0    3101.0  Los Angeles County  California         1   4178.0   4950.0
# 1     139.0         Cook County    Illinois         2   5045.0   5493.0
# 2    1090.0       Harris County       Texas         3      NaN      NaN
# 3    2402.0     Maricopa County     Arizona         4   4398.0   5112.0
# 4    2841.0    San Diego County  California         5   2014.0   2635.0
#
#    2008-05  2008-06  2008-07  2008-08   ...     2018-06  2018-07  2018-08  \
# 0   5370.0   5524.0   6239.0   5911.0   ...      8390.0   8108.0   8345.0
# 1   5497.0   6069.0   6693.0   6236.0   ...     10663.0   9214.0   8240.0
# 2      NaN      NaN      NaN      NaN   ...      6223.0   6116.0   6567.0
# 3   5603.0   5655.0   5888.0   5530.0   ...     11935.0  11491.0  11094.0
# 4   2912.0   2784.0   3143.0   2853.0   ...      4043.0   3723.0   3805.0
#
#    2018-09  2018-10  2018-11  2018-12  2019-01  2019-02  2019-03
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   7004.0   7151.0   6198.0   6257.0   4514.0   4450.0   6337.0
# 2   5369.0   5863.0   4958.0   5284.0   3753.0   3956.0   4981.0
# 3   9202.0   9931.0   9268.0   9097.0   8230.0   9161.0  11156.0
# 4   2900.0   3160.0   2691.0   2613.0   2105.0   2437.0   3027.0
#
# [5 rows x 137 columns]

# %%
# Looking for Santa Clara information
santaclara1 = soldhomes[soldhomes.RegionName == 'Santa Clara County']
santaclara1
# Out:
#     RegionID          RegionName   StateName  SizeRank  2008-03  2008-04  \
# 14    3136.0  Santa Clara County  California        15    921.0   1078.0
#
#     2008-05  2008-06  2008-07  2008-08   ...     2018-06  2018-07  2018-08  \
# 14   1268.0   1344.0   1367.0   1323.0   ...      1703.0   1567.0   1641.0
#
#     2018-09  2018-10  2018-11  2018-12  2019-01  2019-02  2019-03
# 14   1313.0   1400.0   1280.0   1021.0    778.0    909.0   1362.0
#
# [1 rows x 137 columns]

# %% [markdown]
# ##### Building new dataframes, so that the relevant data is easily accessable.

# %%
# New Dataframe
santaclara_crash = {'Year': ['2008-06', '2009-06', '2011-06', '2013-06', '2018-06'],
                    'Sold': [1344, 1707, 1609, 1706, 1703]}
df = DataFrame(santaclara_crash, columns = ['Year', 'Sold'])
print(df)
# Out:
#       Year  Sold
# 0  2008-06  1344
# 1  2009-06  1707
# 2  2011-06  1609
# 3  2013-06  1706
# 4  2018-06  1703

# %% [markdown]
# ##### Visualizing the data so far.

# %%
# Plotting Graph 2.1
graph_21 = sns.pointplot(x = df.Year, y = df.Sold, color = 'green')

# Twisting Labels for fitting
twist(graph_21)

# %%
# Saving Graph 2.1
fig = graph_21.get_figure()
fig.savefig('group11_graph21.png', bbox_inches = 'tight')

# %% [markdown]
# ##### Looking at Los Angeles county, California

# %%
# Los Angeles County
Los_angeles_crash = {'Year': ['2008-06', '2009-06', '2011-06', '2013-06', '2018-06'],
                    'Sold': [5524, 7483, 6868, 7595, 8390]}
df1 = DataFrame(Los_angeles_crash, columns = ['Year', 'Sold'])
print(df1)
# Out:
#       Year  Sold
# 0  2008-06  5524
# 1  2009-06  7483
# 2  2011-06  6868
# 3  2013-06  7595
# 4  2018-06  8390

# %%
# Plotting Graph 2.2
graph_22 = sns.pointplot(x = df1.Year, y = df1.Sold, color = 'orange')

# Twisting Labels for fitting
twist(graph_22)

# %%
# Saving Graph 2.2
fig = graph_22.get_figure()
fig.savefig('group11_graph22.png', bbox_inches = 'tight')

# %% [markdown]
# ##### Looking at Dallas county, Texas

# %%
# Dallas County
Dallas_crash = {"Year": ['2008-06', '2009-06', '2011-06', '2013-06', '2018-06'],
                    'Sold': [2552, 1847, 2197, 2486, 3074]}
df2 = DataFrame(Dallas_crash, columns = ['Year', 'Sold'])
print(df2)
# Out:
#       Year  Sold
# 0  2008-06  2552
# 1  2009-06  1847
# 2  2011-06  2197
# 3  2013-06  2486
# 4  2018-06  3074

# %%
# Plotting Graph 2.3
graph_23 = sns.pointplot(x = df2.Year, y = df2.Sold)

# Twisting Labels for fitting
twist(graph_23)

# %%
# Saving Graph 2.3
fig = graph_23.get_figure()
fig.savefig('group11_graph23.png', bbox_inches = 'tight')

# %% [markdown]
# ##### Looking at Denver county, Colorado

# %%
# Denver County
Denver_crash = {'Year': ['2008-06', '2009-06', '2011-06', '2013-06', '2018-06'],
                    'Sold': [1277, 1183, 1037, 1465, 1531]}
df3 = DataFrame(Denver_crash, columns = ['Year', 'Sold'])
print(df3)
# Out:
#       Year  Sold
# 0  2008-06  1277
# 1  2009-06  1183
# 2  2011-06  1037
# 3  2013-06  1465
# 4  2018-06  1531

# %%
# Plotting Graph 2.4
graph_24 = sns.pointplot(x = df3.Year, y = df3.Sold, color = 'purple')

# Twisting Labels for fitting
twist(graph_24)

# %%
# Saving Graph 2.4
fig = graph_24.get_figure()
fig.savefig('group11_graph24.png', bbox_inches = 'tight')

# %% [markdown]
# ##### Putting everything together into one dataframe and graph.

# %%
# Putting everything together
counties = ['Santa Clara County', 'Santa Clara County', 'Santa Clara County', 'Santa Clara County',
            'Santa Clara County', 'Los Angeles County', 'Los Angeles County', 'Los Angeles County',
            'Los Angeles County',  'Los Angeles County', 'Dallas County', 'Dallas County', 'Dallas County',
            'Dallas County', 'Dallas County', 'Denver County', 'Denver County', 'Denver County', 'Denver County',
           'Denver County']
dfs = [df, df1, df2, df3]

# Concatenating dataframes
result = pd.concat(dfs)

result['County'] = counties
result
# Out:
#       Year  Sold              County
# 0  2008-06  1344  Santa Clara County
# 1  2009-06  1707  Santa Clara County
# 2  2011-06  1609  Santa Clara County
# 3  2013-06  1706  Santa Clara County
# 4  2018-06  1703  Santa Clara County
# 0  2008-06  5524  Los Angeles County
# 1  2009-06  7483  Los Angeles County
# 2  2011-06  6868  Los Angeles County
# 3  2013-06  7595  Los Angeles County
# 4  2018-06  8390  Los Angeles County
# 0  2008-06  2552       Dallas County
# 1  2009-06  1847       Dallas County
# 2  2011-06  2197       Dallas County
# 3  2013-06  2486       Dallas County
# 4  2018-06  3074       Dallas County
# 0  2008-06  1277       Denver County
# 1  2009-06  1183       Denver County
# 2  2011-06  1037       Denver County
# 3  2013-06  1465       Denver County
# 4  2018-06  1531       Denver County

# %%
# Graph with all analyzed counties
graph_2 = sns.pointplot(x = result.Year, y = result.Sold, hue = result.County)

# %%
# Saving Graph 2
fig = graph_2.get_figure()
fig.savefig('group11_graph2.png', bbox_inches = 'tight')

# %% [markdown]
# ### GRAPH 3 - RENTAL LISTINGS
#
# Purpose: show the increase of the rent for different types of accommodation - Studio, 1 Bedroom, 2 Bedrooms and 3 Bedrooms houses.

# %%
# Santa Clara Rental Studio Data 
sc_studio = pd.read_csv('group11_rental_studio.csv')
sc_studio_col = sc_studio[sc_studio.RegionName == 'Santa Clara County'] 
sc_studio_col
# Out:
#             RegionName State                           Metro  StateCodeFIPS  \
# 14  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara              6
#
#     MunicipalCodeFIPS  SizeRank  2010-02  2010-03  2010-04  2010-05   ...     \
# 14                 85        15      NaN      NaN      NaN      NaN   ...
#
#     2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 14   2597.0   2595.0   2642.5   2600.0   2552.5   2500.0   2500.0   2495.0
#
#     2019-02  2019-03
# 14   2488.0   2550.0
#
# [1 rows x 116 columns]

# %%
# Santa Clara 1 Bedroom Data 
sc_1bed = pd.read_csv('group11_rental_1bed.csv')
sc_1bed_col = sc_1bed[sc_1bed.RegionName == 'Santa Clara County']
sc_1bed_col
# Out:
#             RegionName State                           Metro  StateCodeFIPS  \
# 15  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara              6
#
#     MunicipalCodeFIPS  SizeRank  2010-02  2010-03  2010-04  2010-05   ...     \
# 15                 85        16      NaN      NaN      NaN      NaN   ...
#
#     2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 15   2690.0   2715.0   2690.0   2659.0   2637.0   2610.0   2595.0   2625.5
#
#     2019-02  2019-03
# 15   2651.0   2685.0
#
# [1 rows x 116 columns]

# %%
# Santa Clara 2 Bedrooms Data 
sc_2bed = pd.read_csv('group11_rental_2bed.csv')
sc_2bed_col = sc_2bed[sc_2bed.RegionName == 'Santa Clara County']
sc_2bed_col
# Out:
#             RegionName State                           Metro  StateCodeFIPS  \
# 15  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara              6
#
#     MunicipalCodeFIPS  SizeRank  2010-01  2010-02  2010-03  2010-04   ...     \
# 15                 85        16      NaN      NaN      NaN      NaN   ...
#
#     2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 15   3231.0   3250.0   3200.0   3150.0   3116.0   3091.0   3100.0   3150.0
#
#     2019-02  2019-03
# 15   3172.0   3195.0
#
# [1 rows x 117 columns]

# %%
# Santa Clara 3 Bedrooms Data 
sc_3bed = pd.read_csv('group11_rental_3bed.csv')
sc_3bed_col = sc_3bed[sc_3bed.RegionName == 'Santa Clara County']
sc_3bed_col
# Out:
#             RegionName State                           Metro  StateCodeFIPS  \
# 16  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara              6
#
#     MunicipalCodeFIPS  SizeRank  2010-01  2010-02  2010-03  2010-04   ...     \
# 16                 85        17      NaN      NaN      NaN      NaN   ...
#
#     2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 16   3800.0   3800.0   3750.0   3680.0   3650.0   3650.0   3650.0   3695.0
#
#     2019-02  2019-03
# 16   3695.0   3700.0
#
# [1 rows x 117 columns]

# %%
# New Concatenated DataFrame 
df_types = pd.concat([sc_studio_col, sc_1bed_col, sc_2bed_col, sc_3bed_col], ignore_index = True, sort = False)
df_types
# Out:
#            RegionName State                           Metro  StateCodeFIPS  \
# 0  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara              6
# 1  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara              6
# 2  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara              6
# 3  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara              6
#
#    MunicipalCodeFIPS  SizeRank  2010-02  2010-03  2010-04  2010-05   ...     \
# 0                 85        15      NaN      NaN      NaN      NaN   ...
# 1                 85        16      NaN      NaN      NaN      NaN   ...
# 2                 85        16      NaN      NaN      NaN      NaN   ...
# 3                 85        17      NaN      NaN      NaN      NaN   ...
#
#    2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  2019-02  \
# 0   2595.0   2642.5   2600.0   2552.5   2500.0   2500.0   2495.0   2488.0
# 1   2715.0   2690.0   2659.0   2637.0   2610.0   2595.0   2625.5   2651.0
# 2   3250.0   3200.0   3150.0   3116.0   3091.0   3100.0   3150.0   3172.0
# 3   3800.0   3750.0   3680.0   3650.0   3650.0   3650.0   3695.0   3695.0
#
#    2019-03  2010-01
# 0   2550.0      NaN
# 1   2685.0      NaN
# 2   3195.0      NaN
# 3   3700.0      NaN
#
# [4 rows x 117 columns]

# %% [markdown]
# ##### Here we are adding new columns with the same values as the respective original date column. The goal is to elimate the "-" symbol of the column name:

# %%
# Adding Columns with nice names
n = 2013
while n < 2019:
    df_types['Sept' + str(n)] = df_types.loc[: , [str(n) + '-09']]
    n += 1 
df_types['Mar2019'] = df_types.loc[: , ['2019-03']]

# Checking March 2019
print(df_types.Mar2019)
# Out:
# 0    2550.0
# 1    2685.0
# 2    3195.0
# 3    3700.0
# Name: Mar2019, dtype: float64

# %%
# Checking columns
df_types.columns
# Out:
# Index(['RegionName', 'State', 'Metro', 'StateCodeFIPS', 'MunicipalCodeFIPS',
#        'SizeRank', '2010-02', '2010-03', '2010-04', '2010-05',
#        ...
#        '2019-02', '2019-03', '2010-01', 'Sept2013', 'Sept2014', 'Sept2015',
#        'Sept2016', 'Sept2017', 'Sept2018', 'Mar2019'],
#       dtype='object', length=124)

# %% [markdown]
# ##### Four dataframes were used to get the relevant data and now we need to put the information into a new dataframe:

# %%
# Viewing Relevant Data & Adding new column to specify size of room
new_df_rel = df_types[['Sept2013', 'Sept2014', 'Sept2015',
       'Sept2016', 'Sept2017', 'Sept2018', 'Mar2019']]
size = ['studio', '1bed', '2bed', '3bed'] 
new_df_rel['size'] = size
new_df_rel
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#    Sept2013  Sept2014  Sept2015  Sept2016  Sept2017  Sept2018  Mar2019    size
# 0    1554.5    2084.5    2370.0    2205.0    2303.0    2600.0   2550.0  studio
# 1    1883.5    2303.0    2550.0    2405.0    2507.0    2659.0   2685.0    1bed
# 2    2383.0    2784.0    3135.0    2955.0    2960.0    3150.0   3195.0    2bed
# 3    2900.0    3287.5    3650.0    3495.0    3669.5    3680.0   3700.0    3bed

# %% [markdown]
# ##### Dataframe needs to be transformed into long format for analysis:

# %%
# Wide to Long format 
new_df_long = pd.melt(new_df_rel, id_vars = 'size', var_name = 'date', value_name = 'price')
new_df_long
# Out:
#       size      date   price
# 0   studio  Sept2013  1554.5
# 1     1bed  Sept2013  1883.5
# 2     2bed  Sept2013  2383.0
# 3     3bed  Sept2013  2900.0
# 4   studio  Sept2014  2084.5
# 5     1bed  Sept2014  2303.0
# 6     2bed  Sept2014  2784.0
# 7     3bed  Sept2014  3287.5
# 8   studio  Sept2015  2370.0
# 9     1bed  Sept2015  2550.0
# 10    2bed  Sept2015  3135.0
# 11    3bed  Sept2015  3650.0
# 12  studio  Sept2016  2205.0
# 13    1bed  Sept2016  2405.0
# 14    2bed  Sept2016  2955.0
# 15    3bed  Sept2016  3495.0
# 16  studio  Sept2017  2303.0
# 17    1bed  Sept2017  2507.0
# 18    2bed  Sept2017  2960.0
# 19    3bed  Sept2017  3669.5
# 20  studio  Sept2018  2600.0
# 21    1bed  Sept2018  2659.0
# 22    2bed  Sept2018  3150.0
# 23    3bed  Sept2018  3680.0
# 24  studio   Mar2019  2550.0
# 25    1bed   Mar2019  2685.0
# 26    2bed   Mar2019  3195.0
# 27    3bed   Mar2019  3700.0

# %%
# Plotting Graph 3'
graph_3 = sns.pointplot(x = 'date', y = 'price', hue = 'size', data = new_df_long, 
                        order = ['Sept2013', 'Sept2014', 'Sept2015', 'Sept2016', 'Sept2017', 
                                 'Sept2018', 'Mar2019'])
# Twisting Labels for fitting
twist(graph_3)

# %%
# Saving Graph 3
fig = graph_3.get_figure()
fig.savefig('group11_graph3.png', bbox_inches = 'tight')

# %% [markdown]
# ### GRAPH 4 - PRICE-TO-RENT RATIO
# Purpose: make a comparison between Santa Clara County and other counties in the United States.
#
# Important - What price-to-rental ratio means:
# The price-to-rent ratio shows whether buying or renting would be best for a particular property in a given market.
# - Price to rent ratio of 1 to 15 = typically better to buy than rent;
# - Price to rent ratio of 16 to 20 = getting in to risky buy territory;
# - Price to rent ratio of 21 or more = much better to rent than buy.

# %%
# Dataframe for Graph 4
ratio = pd.read_csv('group11_price_rent_ratio.csv', encoding = 'ISO-8859-1')

# Checking
ratio.head()
# Out:
#    RegionID          RegionName State                             Metro  \
# 0      3101  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook County    IL          Chicago-Naperville-Elgin
# 2      1090       Harris County    TX  Houston-The Woodlands-Sugar Land
# 3      2402     Maricopa County    AZ           Phoenix-Mesa-Scottsdale
# 4      2841    San Diego County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank  2010-10  2010-11  2010-12  \
# 0              6                 37         1    15.26    15.19    15.16
# 1             17                 31         2    10.41    10.28    10.20
# 2             48                201         3     8.36     8.41     8.26
# 3              4                 13         4     9.80     9.66     9.53
# 4              6                 73         5    15.10    15.00    14.86
#
#     ...     2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  \
# 0   ...       18.88    18.88    19.02    18.97    18.95    18.80    18.72
# 1   ...       11.48    11.51    11.46    11.35    11.32    11.02    11.02
# 2   ...        9.99    10.03    10.12    10.26    10.23    10.16    10.18
# 3   ...       15.35    15.44    15.57    15.70    15.65    15.40    15.34
# 4   ...       18.71    18.77    18.89    19.12    19.03    18.61    18.47
#
#    2019-01  2019-02  2019-03
# 0    18.73    18.74    18.69
# 1    11.02    10.98    10.98
# 2    10.20    10.17    10.22
# 3    15.34    15.32    15.29
# 4    18.46    18.33    18.25
#
# [5 rows x 109 columns]

# %%
# Santa Clara County, CA
sc_ratio = ratio[ratio.RegionName == 'Santa Clara County']
sc_ratio
# Out:
#     RegionID          RegionName State                           Metro  \
# 16      3136  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara
#
#     StateCodeFIPS  MunicipalCodeFIPS  SizeRank  2010-10  2010-11  2010-12  \
# 16              6                 85        17    20.28    20.36    20.06
#
#      ...     2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  \
# 16   ...       31.41    31.01    30.38    29.77    29.14    29.05    28.99
#
#     2019-01  2019-02  2019-03
# 16     28.6    28.43     28.1
#
# [1 rows x 109 columns]

# %%
# Los Angeles County, CA
la_ratio = ratio[ratio.RegionName == 'Los Angeles County']
la_ratio
# Out:
#    RegionID          RegionName State                           Metro  \
# 0      3101  Los Angeles County    CA  Los Angeles-Long Beach-Anaheim
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank  2010-10  2010-11  2010-12  \
# 0              6                 37         1    15.26    15.19    15.16
#
#     ...     2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  \
# 0   ...       18.88    18.88    19.02    18.97    18.95     18.8    18.72
#
#    2019-01  2019-02  2019-03
# 0    18.73    18.74    18.69
#
# [1 rows x 109 columns]

# %%
# Denver County,CO
de_ratio = ratio[ratio.RegionName == 'Denver County']
de_ratio
# Out:
#      RegionID     RegionName State                   Metro  StateCodeFIPS  \
# 105       989  Denver County    CO  Denver-Aurora-Lakewood              8
#
#      MunicipalCodeFIPS  SizeRank  2010-10  2010-11  2010-12   ...     2018-06  \
# 105                 31       106    13.78    13.42     12.9   ...       17.03
#
#      2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  2019-02  \
# 105    17.02    17.24    17.47    17.39    17.51    17.35    17.22    17.17
#
#      2019-03
# 105    17.15
#
# [1 rows x 109 columns]

# %%
# Dallas County,TX
da_ratio = ratio[ratio.RegionName == 'Dallas County']

# Choosing the right county
da_ratio1 = da_ratio[da_ratio.State == 'TX']
da_ratio1
# Out:
#    RegionID     RegionName State                        Metro  StateCodeFIPS  \
# 8       978  Dallas County    TX  Dallas-Fort Worth-Arlington             48
#
#    MunicipalCodeFIPS  SizeRank  2010-10  2010-11  2010-12   ...     2018-06  \
# 8                113         9     7.78      7.7     7.61   ...       10.87
#
#    2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  2019-02  \
# 8    10.92    11.05    11.14    11.14    11.19    11.31    11.23    11.15
#
#    2019-03
# 8     11.1
#
# [1 rows x 109 columns]

# %%
# Concatenating dataframes
conc_ratio = pd.concat([sc_ratio, la_ratio, de_ratio, da_ratio1], ignore_index = True, sort = False)
conc_ratio
# Out:
#    RegionID          RegionName State                           Metro  \
# 0      3136  Santa Clara County    CA  San Jose-Sunnyvale-Santa Clara
# 1      3101  Los Angeles County    CA  Los Angeles-Long Beach-Anaheim
# 2       989       Denver County    CO          Denver-Aurora-Lakewood
# 3       978       Dallas County    TX     Dallas-Fort Worth-Arlington
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank  2010-10  2010-11  2010-12  \
# 0              6                 85        17    20.28    20.36    20.06
# 1              6                 37         1    15.26    15.19    15.16
# 2              8                 31       106    13.78    13.42    12.90
# 3             48                113         9     7.78     7.70     7.61
#
#     ...     2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  \
# 0   ...       31.41    31.01    30.38    29.77    29.14    29.05    28.99
# 1   ...       18.88    18.88    19.02    18.97    18.95    18.80    18.72
# 2   ...       17.03    17.02    17.24    17.47    17.39    17.51    17.35
# 3   ...       10.87    10.92    11.05    11.14    11.14    11.19    11.31
#
#    2019-01  2019-02  2019-03
# 0    28.60    28.43    28.10
# 1    18.73    18.74    18.69
# 2    17.22    17.17    17.15
# 3    11.23    11.15    11.10
#
# [4 rows x 109 columns]

# %%
# Renaming relevant column
conc_ratio = conc_ratio.rename(columns = {'2019-03':'nineteen_march'})

# %%
# Plotting Graph 4
ratio_graph = sns.barplot(x = conc_ratio.RegionName, y = conc_ratio.nineteen_march)

# Twisting labels for fitting
twist(ratio_graph)

# %%
# Saving Graph 4
fig = ratio_graph.get_figure()
fig.savefig('group11_graph4.png', bbox_inches = 'tight')

# %% [markdown]
# ### GRAPH 5 - RENT FORECAST
#
# Purpose: make a comparison between the city of San Jose, CA, the national rent forecast, the city with the lowest rent forecast and the city with the highest rent forecast.
#
# Important - Methodology used by Zillow: https://www.zillow.com/research/zillow-home-v

# %%
# Dataframe for Graph 5
df_graph5 = pd.read_csv('group11_rent_forecast.csv')
df_graph5.head()
# Out:
#    RegionID                          RegionName RegionType  SizeRank  \
# 0    102001                       United States    Country         0
# 1    394913                        New York, NY        Msa         1
# 2    753899  Los Angeles-Long Beach-Anaheim, CA        Msa         2
# 3    394463                         Chicago, IL        Msa         3
# 4    394514               Dallas-Fort Worth, TX        Msa         4
#
#    ZriForecast  Forecast_YoY_Change  Current_YoY_Change
# 0         1500             0.017639            0.025035
# 1         2447             0.011575            0.014681
# 2         2923             0.030677            0.033904
# 3         1728             0.021881            0.032357
# 4         1680             0.022520            0.029449

# %%
# City with the lowest rent forecast
lower_rent = df_graph5[df_graph5.ZriForecast == min(df_graph5.ZriForecast)]
lower_rent
# Out:
#     RegionID         RegionName RegionType  SizeRank  ZriForecast  \
# 42    394935  Oklahoma City, OK        Msa        42         1115
#
#     Forecast_YoY_Change  Current_YoY_Change
# 42             0.011797            0.010082

# %%
# City with the highest rent forecast
highest_rent = df_graph5[df_graph5.ZriForecast == max(df_graph5.ZriForecast)]
highest_rent
# Out:
#     RegionID    RegionName RegionType  SizeRank  ZriForecast  \
# 34    395059  San Jose, CA        Msa        34         3656
#
#     Forecast_YoY_Change  Current_YoY_Change
# 34              0.02899            0.015143

# %% [markdown]
# ##### Note: San Jose is actually the city with the highest rent forecast, so the city of San Francisco was chosen, as well , for comparison purposes.

# %%
# Forecast for San Francisco
sanf_forecast = df_graph5[df_graph5.RegionName == 'San Francisco, CA']
sanf_forecast
# Out:
#     RegionID         RegionName RegionType  SizeRank  ZriForecast  \
# 11    395057  San Francisco, CA        Msa        11         3529
#
#     Forecast_YoY_Change  Current_YoY_Change
# 11             0.022899              0.0165

# %%
# US forecast, highest and lowest forecast, SF forecast
my_df = df_graph5.iloc[[0, 11, 34, 42], :]
my_df
# Out:
#     RegionID         RegionName RegionType  SizeRank  ZriForecast  \
# 0     102001      United States    Country         0         1500
# 11    395057  San Francisco, CA        Msa        11         3529
# 34    395059       San Jose, CA        Msa        34         3656
# 42    394935  Oklahoma City, OK        Msa        42         1115
#
#     Forecast_YoY_Change  Current_YoY_Change
# 0              0.017639            0.025035
# 11             0.022899            0.016500
# 34             0.028990            0.015143
# 42             0.011797            0.010082

# %%
# Plotting Graph 5
graph_5 = sns.barplot(x = my_df.RegionName, y = my_df.ZriForecast)

# %%
# Saving Graph 5
fig = graph_5.get_figure()
fig.savefig('group11_graph5.png', bbox_inches = 'tight')

# %% [markdown]
# ### WORD CLOUD - HIGHEST RENTAL PRICES IN THE WORLD
#
# Purpose: Make a comparison between the 50 highest rental prices in the world and show it as a Word Cloud. The highest the rent, the bigger the city will be displayed.

# %%
# Importing libraries and modules
from wordcloud import WordCloud
from PIL import Image

# %%
# Creating Dataframe for Word Cloud
countries = pd.read_csv('group11_cloud.csv')
countries.head()
# Out:
#    Rank                              City     Rent
# 0     1  San Francisco, CA, United States  3397.85
# 1     2       New York, NY, United States  3120.14
# 2     3       San Jose, CA, United States  2560.66
# 3     4       Brooklyn, NY, United States  2517.88
# 4     5        Oakland, CA, United States  2481.65

# %% [markdown]
# A dictionary will be used for associating the name of the city with the value of its rental price. For better visualization, just the main name of the cities will be displayed.

# %%
# Initializing a dictionary
values = {}
# Iterating through values in "City" and "Rent" columns
for n in range(453):
    full_name = countries.City[n]
    city = full_name.split(sep = ',')
    city_name = city[0]
    values[city_name] = countries.Rent[n]

# %% [markdown]
# There are keys with the same name in this dictionary, so just the cities with the highest rents will be maintened:

# %%
# Values in dictionary are for San Jose, CA and London, UK
# "San Jose" in Costa Rica and "London" in Canada were excluded 
values['San Jose'] = 2560.66
values['London'] = 2230.72
values
# Out:
# {'San Francisco': 3397.85,
#  'New York': 3120.14,
#  'San Jose': 2560.66,
#  'Brooklyn': 2517.88,
#  'Oakland': 2481.65,
#  'Boston': 2400.68,
#  'Berkeley': 2377.5,
#  'Hong Kong': 2333.57,
#  'Washington': 2268.54,
#  'London': 2230.72,
#  'Los Angeles': 2139.27,
#  'Ajman': 2105.88,
#  'San Diego': 1990.44,
#  'Seattle': 1987.46,
#  'Singapore': 1978.15,
#  'Geneva': 1933.87,
#  'Dublin': 1923.96,
#  'Miami': 1836.71,
#  'Sydney': 1825.82,
#  'Chicago': 1786.86,
#  'Honolulu': 1766.0,
#  'Amsterdam': 1743.0,
#  'Zurich': 1723.28,
#  'Santa Rosa': 1712.33,
#  'Dubai': 1668.27,
#  'Reykjavik': 1656.38,
#  'Austin': 1652.74,
#  'Denver': 1648.67,
#  'Luxembourg': 1604.21,
#  'Boulder': 1564.29,
#  'Portland': 1555.31,
#  'Nashville': 1540.9,
#  'Toronto': 1538.16,
#  'Sacramento': 1508.1,
#  'Philadelphia': 1501.57,
#  'Doha': 1485.78,
#  'Atlanta': 1480.26,
#  'Vancouver': 1471.64,
#  'Copenhagen': 1437.37,
#  'Abu Dhabi': 1429.97,
#  'Charlotte': 1414.85,
#  'Minneapolis': 1411.96,
#  'Lausanne': 1404.91,
#  'Oxford': 1384.52,
#  'Dallas': 1372.51,
#  'Tampa': 1370.48,
#  'Orlando': 1360.24,
#  'Oslo': 1353.45,
#  'Cambridge': 1353.18,
#  'Baltimore': 1352.67,
#  'Houston': 1341.5,
#  'Melbourne': 1338.06,
#  'Tel Aviv-Yafo': 1333.0,
#  'Paris': 1315.39,
#  'Lugano': 1300.55,
#  'Mississauga': 1285.44,
#  'Munich': 1259.62,
#  'Brighton': 1250.84,
#  'Canberra': 1248.95,
#  'Gold Coast': 1248.15,
#  'Anchorage': 1235.0,
#  'Stockholm': 1231.7,
#  'Auckland': 1223.22,
#  'Rotterdam': 1220.05,
#  'Basel': 1218.38,
#  'Raleigh': 1214.35,
#  'Cork': 1207.94,
#  'Trondheim': 1205.79,
#  'Richmond': 1205.43,
#  'Detroit': 1201.11,
#  'Brisbane': 1196.37,
#  'Asheville': 1192.65,
#  'Madison': 1190.83,
#  'Phoenix': 1188.82,
#  'Tacoma': 1188.8,
#  'Milan': 1158.27,
#  'Indianapolis': 1148.65,
#  'Lagos': 1148.35,
#  'Salt Lake City': 1143.0,
#  'Rome': 1142.79,
#  'Reno': 1142.0,
#  'Wellington': 1140.47,
#  'Utrecht': 1138.56,
#  'The Hague (Den Haag)': 1122.97,
#  'San Antonio': 1122.56,
#  'Stavanger': 1121.97,
#  'Bergen': 1121.22,
#  'Bristol': 1121.2,
#  'Pittsburgh': 1117.48,
#  'Victoria': 1101.36,
#  'Tokyo': 1097.3,
#  'Cleveland': 1084.38,
#  'Galway': 1083.55,
#  'Reading': 1062.14,
#  'Barcelona': 1061.56,
#  'Columbus': 1060.74,
#  'Albany': 1047.92,
#  'Colorado Springs': 1042.55,
#  'Jerusalem': 1040.18,
#  'Hamburg': 1038.2,
#  'Cincinnati': 1032.9,
#  'Jacksonville': 1026.11,
#  'Helsinki': 1025.42,
#  'Kansas City': 1017.32,
#  'Milwaukee': 1017.0,
#  'Sliema': 1013.74,
#  'Frankfurt': 1012.38,
#  'Boise': 1012.25,
#  'Madrid': 1011.29,
#  'Ramat Gan': 1008.71,
#  'Edinburgh': 999.25,
#  'Bern': 993.07,
#  'Lisbon': 990.97,
#  'Shanghai': 989.83,
#  'Manchester': 988.35,
#  'Eindhoven': 988.07,
#  'Berlin': 987.94,
#  'Arhus': 987.8,
#  'Beijing': 985.1,
#  'Kuwait City': 984.4,
#  'Perth': 983.83,
#  'Las Vegas': 976.93,
#  'Buffalo': 975.83,
#  'Leiden': 975.72,
#  'Ottawa': 972.96,
#  'Stuttgart': 963.19,
#  'Saint Louis': 962.87,
#  'Vienna': 962.8,
#  'Adelaide': 962.79,
#  'Palma de Mallorca': 955.12,
#  'Birmingham': 954.11,
#  'Calgary': 953.93,
#  'Suva': 953.2,
#  'Kelowna': 952.32,
#  'Panama City': 951.79,
#  'Edmonton': 948.59,
#  'Eugene': 943.75,
#  'Gothenburg': 940.05,
#  'Nassau': 936.36,
#  'Brussels': 919.88,
#  'Manama': 915.59,
#  'Southampton': 913.45,
#  'Swindon': 911.78,
#  'Limerick': 910.17,
#  'Exeter': 909.35,
#  'Knoxville': 904.17,
#  'Cardiff': 902.08,
#  'Memphis': 901.82,
#  'Beirut': 896.09,
#  'Christchurch': 887.54,
#  'Maastricht': 883.2,
#  'Rochester': 881.29,
#  'Moscow': 878.75,
#  'Albuquerque': 873.1,
#  'Spokane': 868.0,
#  'Delft': 867.09,
#  'Florence': 865.37,
#  'Liverpool': 859.07,
#  'Limassol': 856.99,
#  'Montreal': 850.38,
#  'Coventry': 848.92,
#  'Belfast': 841.2,
#  'Leeds': 840.28,
#  'Fresno': 838.75,
#  'Halifax': 838.7,
#  'Groningen': 836.73,
#  'Glasgow': 826.22,
#  'Hobart': 822.41,
#  'Cologne': 820.81,
#  'Louisville': 819.63,
#  'Regina': 819.62,
#  'Kitchener': 818.8,
#  'Tulsa': 817.63,
#  'Newcastle upon Tyne': 807.43,
#  'Darwin': 806.01,
#  'Prague': 801.05,
#  'Little Rock': 797.64,
#  'Freiburg im Breisgau': 794.59,
#  'Gent': 792.69,
#  'Malmo': 784.77,
#  'Bonn': 784.52,
#  'Dusseldorf': 782.78,
#  'Dunedin': 781.87,
#  'Antwerp': 780.14,
#  'Hamilton': 766.24,
#  'Sheffield': 762.38,
#  'Aberdeen': 761.72,
#  'Bologna': 761.06,
#  'Leuven': 760.63,
#  'Uppsala': 760.0,
#  'Nottingham': 758.27,
#  'Leicester': 757.7,
#  'Tampere': 757.38,
#  'Lyon': 755.39,
#  'Porto': 752.84,
#  'Cape Town': 751.45,
#  'Nuremberg': 750.72,
#  'Sharjah': 748.69,
#  'Tucson': 741.67,
#  'Aalborg': 735.37,
#  'Shenzhen': 731.02,
#  'Malaga': 730.38,
#  'Hanover': 728.34,
#  'Red Deer': 715.75,
#  'San Juan': 715.0,
#  'Winnipeg': 713.93,
#  'Saskatoon': 705.65,
#  'Heidelberg': 703.49,
#  'Linz': 697.5,
#  'Muscat': 693.5,
#  'Bangkok': 688.72,
#  'Seoul': 688.29,
#  'Lille': 684.11,
#  'Seville (Sevilla)': 683.66,
#  'Osaka': 682.57,
#  'Las Palmas de Gran Canaria': 681.69,
#  'Toulouse': 672.72,
#  "Saint John's": 670.24,
#  'Bratislava': 668.84,
#  'Valencia': 657.1,
#  'Dundee': 646.63,
#  'Haifa': 642.97,
#  'Warsaw': 642.51,
#  'Derby': 635.04,
#  'Santa Cruz de Tenerife': 634.87,
#  'Karlsruhe': 632.62,
#  'Genoa': 631.88,
#  'Strasbourg': 630.07,
#  'Padova': 624.26,
#  'Mannheim': 622.7,
#  'Graz': 617.95,
#  'Kingston upon Hull': 616.86,
#  'Aachen': 612.86,
#  'Bremen': 609.96,
#  'Turin': 609.2,
#  'Ljubljana': 600.56,
#  'Dresden': 593.05,
#  'Taipei': 591.16,
#  'Wroclaw': 590.2,
#  'Naples': 586.8,
#  'Guangzhou': 585.55,
#  'Leipzig': 575.58,
#  'Kuala Lumpur': 572.26,
#  'Tallinn': 570.9,
#  'Tehran': 567.14,
#  'Brno': 563.04,
#  'Mumbai': 563.0,
#  'Krakow (Cracow)': 555.75,
#  'Port of Spain': 553.33,
#  'Manila': 552.3,
#  'Vilnius': 546.24,
#  'Nicosia': 545.62,
#  'Gdansk': 545.0,
#  'Kiev': 539.18,
#  'Saint Petersburg': 537.85,
#  'Palermo': 533.74,
#  'Granada': 528.66,
#  'Budapest': 522.14,
#  'Alicante': 520.63,
#  'Kosice': 519.7,
#  'Pattaya': 518.0,
#  'Mexico City': 515.49,
#  'Phnom Penh': 510.65,
#  'Zagreb': 501.64,
#  'Quebec City': 499.58,
#  'Sao Paulo': 493.77,
#  'Guatemala City': 488.98,
#  'Montevideo': 486.36,
#  'Kingston': 484.14,
#  'Guayaquil': 482.14,
#  'San Salvador': 478.12,
#  'Larnaca': 477.56,
#  'Lima': 477.08,
#  'Santiago': 473.64,
#  'Cebu': 466.29,
#  'Coimbra': 461.22,
#  'Nairobi': 457.81,
#  'Johannesburg': 457.26,
#  'Rio de Janeiro': 456.0,
#  'Casablanca': 450.9,
#  'Ho Chi Minh City': 450.52,
#  'Baghdad': 442.72,
#  'Poznan': 442.55,
#  'Lublin': 440.16,
#  'Gdynia': 439.15,
#  'Paphos': 439.05,
#  'Bucharest': 435.95,
#  'Tartu': 429.8,
#  'Rabat': 426.09,
#  'Riga': 423.65,
#  'Split': 421.66,
#  'Amman': 421.61,
#  'Cluj-Napoca': 417.45,
#  'Quito': 416.67,
#  'Olomouc': 411.3,
#  'Irbil': 409.17,
#  'Riyadh': 408.15,
#  'Sofia': 405.55,
#  'Bydgoszcz': 405.16,
#  'Catania': 399.84,
#  'Kaunas': 398.6,
#  'Petaling Jaya': 391.78,
#  'Athens': 387.89,
#  'Ad Dammam': 387.74,
#  'Pretoria': 387.59,
#  'Cancun': 385.29,
#  'Santo Domingo': 384.08,
#  'Jakarta': 382.89,
#  'Bogota': 379.85,
#  'Debrecen': 377.72,
#  'Szczecin': 377.68,
#  'Harare': 376.25,
#  'Belgrade': 373.02,
#  'Lodz': 372.25,
#  'Phuket': 370.07,
#  'Chiang Mai': 365.69,
#  'Novosibirsk': 360.88,
#  'Santa Cruz': 359.77,
#  'Cuenca': 359.5,
#  'Thessaloniki': 358.9,
#  'Katowice': 355.06,
#  'Yerevan': 354.86,
#  'Minsk': 354.02,
#  'Brasilia': 352.93,
#  'Lviv': 350.57,
#  'Durban': 348.44,
#  'Kazan': 348.21,
#  'Chengdu': 344.86,
#  'Florianopolis': 344.65,
#  'Klaipeda': 344.12,
#  'Yekaterinburg': 341.68,
#  'Brasov': 341.0,
#  'Maribor': 338.61,
#  'Nizhny Novgorod': 337.47,
#  'Hanoi': 337.4,
#  'Podgorica': 334.86,
#  'Kharkiv': 333.32,
#  'La Paz': 332.43,
#  'Rijeka': 332.23,
#  'Heraklion': 331.39,
#  'Ulaanbaatar': 326.03,
#  'Astana': 324.89,
#  'Timisoara': 324.76,
#  'Tirana': 322.68,
#  'Dnipro': 321.91,
#  'Monterrey': 320.81,
#  'Port Louis': 318.39,
#  'Tijuana': 318.07,
#  'Perm': 317.31,
#  'Krasnodar': 317.25,
#  'Ostrava': 316.51,
#  'Jeddah (Jiddah)': 314.22,
#  'Kota Kinabalu': 312.58,
#  'Tbilisi': 308.61,
#  'Bali': 308.47,
#  'Almaty': 307.94,
#  'Odessa': 306.71,
#  'Samara': 306.43,
#  'Iasi': 305.65,
#  'Salvador': 304.81,
#  'Baku': 303.85,
#  'Belo Horizonte': 301.66,
#  'Buenos Aires': 300.77,
#  'Guadalajara': 299.53,
#  'Campinas': 299.13,
#  'Szeged': 296.76,
#  'Ufa': 295.07,
#  'Istanbul': 294.39,
#  'Dumaguete': 293.32,
#  'Sibiu': 285.81,
#  'Sarajevo': 284.35,
#  'Pristina': 283.73,
#  'Curitiba': 280.77,
#  'Queretaro': 279.61,
#  'Bishkek': 277.89,
#  'Ploiesti': 277.36,
#  'Varna': 274.31,
#  'Porto Alegre': 270.01,
#  'Krasnoyarsk': 269.72,
#  'Arad': 268.44,
#  'Plovdiv': 264.65,
#  'Algiers': 262.99,
#  'Recife': 261.66,
#  'Patras': 260.13,
#  'Gurgaon': 260.07,
#  'Port Elizabeth': 259.87,
#  'Kampala': 256.96,
#  'Chisinau': 255.6,
#  'Novi Sad': 254.44,
#  'Tomsk': 253.51,
#  'Medellin': 253.16,
#  'Osijek': 251.88,
#  'Colombo': 250.71,
#  'Tashkent': 250.26,
#  'Constanta': 247.79,
#  'Thane': 247.27,
#  'Merida': 246.44,
#  'Skopje': 246.28,
#  'Craiova': 245.94,
#  'Surabaya': 242.89,
#  'Oradea': 242.48,
#  'Chelyabinsk': 240.92,
#  'Bangalore': 240.77,
#  'Voronezh': 232.8,
#  'Asuncion': 231.76,
#  'Banja Luka': 230.69,
#  'Bandung': 226.21,
#  'Burgas': 224.97,
#  'Delhi': 224.33,
#  'Davao': 223.88,
#  'Penang': 220.67,
#  'Pune': 219.72,
#  'Izmir': 216.95,
#  'Paramaribo': 213.32,
#  'Cairo': 207.82,
#  'Caracas': 203.0,
#  'Barranquilla': 202.86,
#  'Navi Mumbai': 195.54,
#  'Ankara': 191.1,
#  'Chennai': 190.69,
#  'Islamabad': 181.58,
#  'Tunis': 179.6,
#  'Kathmandu': 170.26,
#  'Hyderabad': 166.11,
#  'Bursa': 165.58,
#  'Cali': 165.04,
#  'Antalya': 164.87,
#  'Goa': 163.01,
#  'Noida': 161.26,
#  'Jaipur': 153.07,
#  'Dhaka': 151.54,
#  'Chandigarh': 151.0,
#  'Kochi': 150.56,
#  'Yogyakarta': 148.65,
#  'Karachi': 145.79,
#  'Kolkata': 144.11,
#  'Coimbatore': 141.47,
#  'Lahore': 133.52,
#  'Ahmedabad': 133.23,
#  'Alexandria': 133.11,
#  'Vijayawada': 131.9,
#  'Thiruvananthapuram': 123.2,
#  'Visakhapatnam': 115.62,
#  'Vadodara': 114.45,
#  'Lucknow (Lakhnau)': 114.4,
#  'Mysore': 114.26,
#  'Guwahati': 112.34,
#  'Indore': 106.7,
#  'Rawalpindi': 105.91,
#  'Bhubaneswar': 105.08,
#  'Bhopal': 101.51}

# %%
# Word Cloud based on key:values in the dictionary
wc = WordCloud(background_color = 'white', width = 4000, height = 2000, 
               max_words = 50, relative_scaling = 0.5, normalize_plurals = False).generate_from_frequencies(values)
plt.imshow(wc)

# %%
# Saving Word Cloud
wc.to_file('wordcloud_6.png')

# %% [markdown]
# ## THE END.
